# %%
from tiny_data_warehouse.social.social_warehouse import SocialWarehouse
import pandas as pd

df = SocialWarehouse().read('world_bank.gdp')
df = df[df['Country Name'] == 'Brazil']

df = df.to_dict(orient='records')

data = []
for i in range(2000, 2023):
    data.append([i, df[0][str(i)]])

df = pd.DataFrame(data, columns=['year', 'gdp'])


df
# Out:
#     year       gdp
# 0   2000  4.387949
# 1   2001  1.389896
# 2   2002  3.053462
# 3   2003  1.140829
# 4   2004  5.759965
# 5   2005  3.202132
# 6   2006  3.961989
# 7   2007  6.069871
# 8   2008  5.094195
# 9   2009 -0.125812
# 10  2010  7.528226
# 11  2011  3.974423
# 12  2012  1.921176
# 13  2013  3.004823
# 14  2014  0.503956
# 15  2015 -3.545763
# 16  2016 -3.275917
# 17  2017  1.322869
# 18  2018  1.783667
# 19  2019  1.220778
# 20  2020 -3.276759
# 21  2021  4.988850
# 22  2022  2.900531

# %%
df.plot(x='year', y='gdp', kind='line')

brazil_presidents = {
    'Fernando Henrique Cardoso': [1995, 2002],
    'Luiz Inácio Lula da Silva': [2003, 2010],
    'Dilma Rousseff': [2011, 2016],
    'Michel Temer': [2016, 2018],
    'Jair Bolsonaro': [2019, 2022]
}
